# %%
# !pip install ultralytics

# %% [markdown]
# ### Mounting google drive to access the data that has been annotated for training

# %%
from google.colab import drive
drive.mount('/content/drive')
folder_path = "/content/drive/MyDrive/<folder_for_yolo_training_data>"

# %% [markdown]
# ### Training the YOLO model on the annotated dataset

# %%
from ultralytics import YOLO

model = YOLO("yolo11s.pt")

res = model.train(data= f"{folder_path}/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %% [markdown]
# ### Copying the folder containing the finetuned weights to google drive

# %%
# !cp -r "/content/runs" "/content/drive/MyDrive/<save_folder_name>"

# %% [markdown]
# ### Using a sample video (not present in the training set) to check the effectiveness of the trained model on identifying cricket ball

# %%
result = model.predict(
    "/content/drive/MyDrive/<video_folder>/<video>.mov",
    save=True,
    conf=0.5,
)

# %%
# !cp -r "runs/detect/predict/<video>.avi" "/content/drive/MyDrive/"
